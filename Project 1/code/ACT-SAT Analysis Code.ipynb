# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## <span style="color:green"> My Problem Statement:
#
# As an analyst in the United States Department of Education, I have been tasked to investigate if states that have a higher exam participation rate perform better than states with lower participation rates. If so, it would provide strong grounds for states to mandate that all students participate in the ACT/SAT.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites:
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# The U.S. Department of Education is the agency of the federal government that establishes policies for education. In 2017, 2.03 million high school students took the ACT <sup> 1 </sup>, and 1.8 million students took the SAT <sup> 2 </sup>. By studying the relationship between participation rates and test scores, it can give recommendations on whether mandating students to partcipate in ACT/SAT is beneficial in raising education standards in the country.

# %% [markdown]
# ## <span style="color:green"> My Datasets:
#
# 1. act_2017.csv: 2017 ACT Scores by State
# 2. act_2018.csv: 2018 ACT Scores by State
# 3. sat_2017.csv: 2017 SAT Scores by State
# 4. sat_2018.csv: 2018 SAT Scores by State

# %% [markdown]
# ## <span style="color:green"> My Outside Research:
#
# 1. https://www.act.org/content/dam/act/unsecured/documents/cccr2017/CCCR_National_2017.pdf (ACT participation figures)
#
# 2. https://reports.collegeboard.org/archive/sat-suite-program-results/2017/overview#:~:text=The%20class%20of%202017%20is,takers%20took%20the%20new%20SAT (SAT participation figures)
#
# 3. https://www.statista.com/statistics/259865/percentage-of-hispanic-population-in-the-us-by-state/ (Hispanic Breakdown)
#
# 4. https://worldpopulationreview.com/states/states-by-race (Breakdown by Ethnicity)
#
# 5. https://cdn.americanprogress.org/content/uploads/2018/11/08042733/LessonsLearned_SchoolFunding-report-4.pdf (Less funding)
#
# 6. https://www.coloradoindependent.com/2017/07/06/from-csap-to-parcc-heres-how-colorados-standardized-tests-have-changed-and-whats-next/ (Colorado switch to SAT)
#
# 7. https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html (Illinois switch to SAT)
#
# 8. https://www.alaskapublic.org/2016/07/01/alaska-changes-hs-diploma-requirements-no-more-sat-act/ (Alaska drop ACT/SAT for diploma)
#
# 9. https://blog.prepscholar.com/average-sat-and-act-scores-by-stated-adjusted-for-participation-rate (Selection Bias of participation rates)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
def mean_calc(list_1):
    return sum(list_1)/len(list_1)

mean_calc([10,20,30])
# Out:
# 20.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def sigma(list_1):
    
    total = 0
    for i in list_1:
        
        total+=(i - mean_calc(list_1))**2
    
    final = np.sqrt(total/len(list_1))
    
    return final

sigma(pd.Series([10,20,30,40,50,60]))
# Out:
# 17.07825127659933

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def pct_remove(str_1):
    return float(str_1.split('%')[0])/100

pct_remove('5%')
# Out:
# 0.05

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
sat_2017_df = pd.read_csv("../data/sat_2017.csv")
sat_2018_df = pd.read_csv("../data/sat_2018.csv")

act_2017_df = pd.read_csv("../data/act_2017.csv")
act_2018_df = pd.read_csv("../data/act_2018.csv")

# %%
# replace '52' to '524' typo

outlier_1 = sat_2017_df[sat_2017_df['Math']==52].index

sat_2017_df.loc[outlier_1,'Math'] = 524

sat_2017_df.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# checking number of rows and columns of data
sat_2017_df.shape
# Out:
# (51, 5)

# %%
#display first 5 rows

act_2017_df.head()
act_2018_df.head()
sat_2017_df.head()
sat_2018_df.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# Checking on descriptive statistics

act_2017_df.describe()
act_2018_df.describe()
sat_2017_df.describe()
sat_2018_df.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
# Check for missing values

sat_2017_na_df = sat_2017_df[sat_2017_df.isna().any(axis=1)]
sat_2018_na_df = sat_2018_df[sat_2018_df.isna().any(axis=1)]
act_2017_na_df = act_2017_df[act_2017_df.isna().any(axis=1)]
act_2018_na_df = act_2018_df[act_2018_df.isna().any(axis=1)]

sat_2017_na_df
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %%
#changing the 20.2x to 20.2

act_2017_df.loc[51,'Composite'] = 20.2

act_2017_df['Composite'][51]
# Out:
# 20.2

# %%
#checking data types
act_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Changing Composite type to float

act_2017_df['Composite'] = pd.to_numeric(act_2017_df['Composite'])
act_2018_df['Composite'] = pd.to_numeric(act_2018_df['Composite'])
act_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB

# %%
#changing typo of 2.3 to 23.2

act_2017_df.loc[act_2017_df['Science'] == 2.3,'Science'] = 23.2
act_2017_df
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
#removing percentage % sign

act_2017_df['Participation'] = act_2017_df['Participation'].map(pct_remove)
act_2018_df['Participation'] = act_2018_df['Participation'].map(pct_remove)

sat_2017_df['Participation'] = sat_2017_df['Participation'].map(pct_remove)
sat_2018_df['Participation'] = sat_2018_df['Participation'].map(pct_remove)

# %%
#drop duplicate maine in 2018 act

act_2018_df.drop_duplicates(keep='first',inplace=True)
act_2018_df.reset_index(inplace=True,drop=True)

# %%
#Changing all column names to lower case

act_2017_df.columns = [x.lower() for x in act_2017_df.columns]
act_2018_df.columns = [x.lower() for x in act_2018_df.columns]
sat_2017_df.columns = [x.lower() for x in sat_2017_df.columns]
sat_2018_df.columns = [x.lower() for x in sat_2018_df.columns]
sat_2018_df.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
# Capitalize C in Columbia

act_2018_df.loc[act_2018_df['state'] == 'District of columbia','state'] = 'District of Columbia'
act_2018_df.head(8)
# Out:
#          state  participation  composite
# 0      Alabama           1.00       19.1
# 1       Alaska           0.33       20.8
# 2      Arizona           0.66       19.2
# 3     Arkansas           1.00       19.4
# 4   California           0.27       22.7
# 5     Colorado           0.30       23.9
# 6  Connecticut           0.26       25.6
# 7     Delaware           0.17       23.8

# %%
#add suffix to act and merge

act_2017_df = act_2017_df.add_suffix('_2017')
act_2018_df = act_2018_df.add_suffix('_2018')

act_2017_df.rename(columns = {'state_2017':"state"},inplace=True)
act_2018_df.rename(columns = {'state_2018':"state"},inplace=True)

act_df = pd.merge(act_2017_df,act_2018_df, how = 'outer', on = 'state')

# %%
# drop national
act_df.dropna(inplace=True)
act_df.reset_index(inplace=True,drop=True)

# %%
#add suffix to sat and merge

sat_2017_df = sat_2017_df.add_suffix('_2017')
sat_2018_df = sat_2018_df.add_suffix('_2018')

sat_2017_df.rename(columns={'state_2017':'state'},inplace=True)
sat_2018_df.rename(columns={'state_2018':'state'},inplace=True)
sat_df = pd.merge(sat_2017_df,sat_2018_df,how='outer',on='state')
sat_df.reset_index(inplace=True,drop=True)
sat_df.head()
# Out:
#         state  participation_2017  evidence-based reading and writing_2017  \
# 0     Alabama                0.05                                      593
# 1      Alaska                0.38                                      547
# 2     Arizona                0.30                                      563
# 3    Arkansas                0.03                                      614
# 4  California                0.53                                      531
#
#    math_2017  total_2017  participation_2018  \
# 0        572        1165                0.06
# 1        533        1080                0.43
# 2        553        1116                0.29
# 3        594        1208                0.05
# 4        524        1055                0.60
#
#    evidence-based reading and writing_2018  math_2018  total_2018
# 0                                      595        571        1166
# 1                                      562        544        1106
# ...

# %%
# joining sat and act together, keeping only relevant columns

act_exams_df = pd.merge(act_2017_df,act_2018_df,how = 'outer',on = 'state')
act_exams_df.drop(['english_2017','math_2017','reading_2017','science_2017'],axis=1,inplace=True)

sat_exams_df = pd.merge(sat_2017_df,sat_2018_df, how = 'outer',on = 'state')
sat_exams_df.drop(['evidence-based reading and writing_2017','math_2017','evidence-based reading and writing_2018','math_2018'],axis=1,inplace=True)

act_exams_df = act_exams_df.add_prefix('act_')
sat_exams_df = sat_exams_df.add_prefix('sat_')

act_exams_df.rename(columns = {'act_state': 'state'},inplace=True)
sat_exams_df.rename(columns = {'sat_state': 'state'},inplace=True)

exams_df = pd.merge(act_exams_df,sat_exams_df, how='outer',on='state')

#drop National
exams_na_df = exams_df[exams_df.isna().any(axis=1)]
display(exams_na_df)

exams_df.dropna(inplace=True)
exams_df.reset_index(inplace=True,drop=True)

#save to csv
exams_df.to_csv('exams_df.csv')

exams_df.head()
# Out:
#       state  act_participation_2017  act_composite_2017  \
# 0  National                     0.6                21.0
#
#    act_participation_2018  act_composite_2018  sat_participation_2017  \
# 0                     NaN                 NaN                     NaN
#
#    sat_total_2017  sat_participation_2018  sat_total_2018
# 0             NaN                     NaN             NaN
#         state  act_participation_2017  act_composite_2017  \
# 0     Alabama                    1.00                19.2
# 1      Alaska                    0.65                19.8
# 2     Arizona                    0.62                19.7
# 3    Arkansas                    1.00                19.4
# 4  California                    0.31                22.8
#
#    act_participation_2018  act_composite_2018  sat_participation_2017  \
# 0                    1.00                19.1                    0.05
# 1                    0.33                20.8                    0.38
# ...

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# **Exams_df:**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|Str|ACT/SAT|States of ACT/SAT data|
# |act_participation_2017|float|ACT|Participation rate for 2017 ACT|
# |sat_participation_2017|float|SAT|Participation rate for 2017 SAT|
# |act_participation_2018|float|ACT|Participation rate for 2018 ACT|
# |sat_participation_2018|float|SAT|Participation rate for 2018 SAT|
# |act_composite_2017|float|ACT|Average state score for 2017 ACT, max 36|
# |act_composite_2018|float|ACT|Average state score for 2018 ACT, max 36|
# |sat_total_2017|float|SAT|Average state score for 2017 SAT, max 1600|
# |sat_total_2018|float|SAT|Average state score for 2018 SAT, max 1600|
#
# **Ethnic_df:**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|Str|Ethnic Data|States of USA|
# |WhiteTotalPerc|float|Ethnic Data|Percentage of White persons by State|
# |BlackTotalPerc|float|Ethnic Data|Percentage of Black persons by State|
# |IndianTotalPerc|float|Ethnic Data|Percentage of Indians by State|
# |AsianTotalPerc|float|Ethnic Data|Percentage of Asians by State|
# |HawaiianTotalPerc|float|Ethnic Data|Percentage of Hawaiians by State|
# |OtherTotalPerc|float|Ethnic Data|Percentage of persons not categorized under any of the above ethnicities|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Summary statistics
sat_df.describe()
act_df.describe()
# Out:
#        participation_2017  english_2017  math_2017  reading_2017  \
# count           51.000000     51.000000  51.000000     51.000000
# mean             0.652549     20.931373  21.182353     22.013725
# std              0.321408      2.353677   1.981989      2.067271
# min              0.080000     16.300000  18.000000     18.100000
# 25%              0.310000     19.000000  19.400000     20.450000
# 50%              0.690000     20.700000  20.900000     21.800000
# 75%              1.000000     23.300000  23.100000     24.150000
# max              1.000000     25.500000  25.300000     26.000000
#
#        science_2017  composite_2017  participation_2018  composite_2018
# count     51.000000       51.000000           51.000000       51.000000
# mean      21.450980       21.519608            0.617255       21.496078
# std        1.739353        2.020695            0.340371        2.111583
# min       18.200000       17.800000            0.070000       17.700000
# ...

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %%
# Dicionary comprehension to store SD for sat
col = [column for column in sat_df.columns if column != 'state']
sat_sd_dict = {x:sigma(sat_df[x]) for x in col}
sat_sd_dict
# Out:
# {'participation_2017': 0.3492907076664507,
#  'evidence-based reading and writing_2017': 45.21697020437866,
#  'math_2017': 46.65713364485503,
#  'total_2017': 91.58351056778743,
#  'participation_2018': 0.3694661922353942,
#  'evidence-based reading and writing_2018': 47.03460978357609,
#  'math_2018': 47.30194550378352,
#  'total_2018': 93.22742384464433}

# %%
# Dicionary comprehension to store SD for act
col = [column for column in act_df.columns if column != 'state']
act_sd_dict = {x:sigma(act_df[x]) for x in col}
act_sd_dict
# Out:
# {'participation_2017': 0.3182417575123181,
#  'english_2017': 2.3304876369363363,
#  'math_2017': 1.9624620273436781,
#  'reading_2017': 2.0469029314842646,
#  'science_2017': 1.7222161451443676,
#  'composite_2017': 2.000786081581989,
#  'participation_2018': 0.33701735820410317,
#  'composite_2018': 2.090779082141178}

# %%
# top 5 highest participation rates among states

top_5_sat_part_2017 = exams_df.sort_values('sat_participation_2017',ascending = False).head()
top_5_sat_part_2018 = exams_df.sort_values('sat_participation_2018',ascending = False).head()

# 18 states have 100% participation for sat so we have to make sure we head(17)
top_5_act_part_2017 = exams_df.sort_values('act_participation_2017',ascending = False).head(17)
top_5_act_part_2018 = exams_df.sort_values('act_participation_2018',ascending = False).head(17)

top_5_act_part_2018
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 0          Alabama                    1.00                19.2
# 17        Kentucky                    1.00                20.0
# 49       Wisconsin                    1.00                20.5
# 44            Utah                    1.00                20.3
# 42       Tennessee                    1.00                19.8
# 40  South Carolina                    1.00                18.7
# 36        Oklahoma                    1.00                19.4
# 35            Ohio                    0.75                22.0
# 33  North Carolina                    1.00                19.1
# 28          Nevada                    1.00                17.8
# 27        Nebraska                    0.84                21.4
# 26         Montana                    1.00                20.3
# 24     Mississippi                    1.00                18.6
# 18       Louisiana                    1.00                19.5
# ...

# %%
#  top 5 lowest participation rates among states

low_5_sat_part_2017 = exams_df.sort_values('sat_participation_2017',ascending = True).head()
low_5_sat_part_2018 = exams_df.sort_values('sat_participation_2018',ascending = True).head()

low_5_act_part_2017 = exams_df.sort_values('act_participation_2017',ascending = True).head()
low_5_act_part_2018 = exams_df.sort_values('act_participation_2018',ascending = True).head()

low_5_act_part_2018.head()
# Out:
#             state  act_participation_2017  act_composite_2017  \
# 19          Maine                    0.08                24.3
# 39   Rhode Island                    0.21                24.0
# 29  New Hampshire                    0.18                25.5
# 7        Delaware                    0.18                24.1
# 38   Pennsylvania                    0.23                23.7
#
#     act_participation_2018  act_composite_2018  sat_participation_2017  \
# 19                    0.07                24.0                    0.95
# 39                    0.15                24.2                    0.71
# 29                    0.16                25.1                    0.96
# 7                     0.17                23.8                    1.00
# 38                    0.20                23.5                    0.65
#
#     sat_total_2017  sat_participation_2018  sat_total_2018
# 19          1012.0                    0.99          1013.0
# ...

# %%
# top 5 highest sat(total) & act(composite) scores among states

top_5_sat_score_2017 = exams_df.sort_values('sat_total_2017',ascending = False).head()
top_5_sat_score_2018 = exams_df.sort_values('sat_total_2018',ascending = False).head()

top_5_act_score_2017 = exams_df.sort_values('act_composite_2017',ascending = False).head()
top_5_act_score_2018 = exams_df.sort_values('act_composite_2018',ascending = False).head()

top_5_act_score_2017
# Out:
#                    state  act_participation_2017  act_composite_2017  \
# 29         New Hampshire                    0.18                25.5
# 21         Massachusetts                    0.29                25.4
# 6            Connecticut                    0.31                25.2
# 19                 Maine                    0.08                24.3
# 8   District of Columbia                    0.32                24.2
#
#     act_participation_2018  act_composite_2018  sat_participation_2017  \
# 29                    0.16                25.1                    0.96
# 21                    0.25                25.5                    0.76
# 6                     0.26                25.6                    1.00
# 19                    0.07                24.0                    0.95
# 8                     0.32                23.6                    1.00
#
#     sat_total_2017  sat_participation_2018  sat_total_2018
# 29          1052.0                    0.96          1063.0
# ...

# %%
# top 5 lowest sat(total) & act(composite) scores among states

low_5_sat_score_2017 = exams_df.sort_values('sat_total_2017',ascending = True).head()
low_5_sat_score_2018 = exams_df.sort_values('sat_total_2018',ascending = True).head()

low_5_act_score_2017 = exams_df.sort_values('act_composite_2017',ascending = True).head()
low_5_act_score_2018 = exams_df.sort_values('act_composite_2018',ascending = True).head()

low_5_act_score_2018
# Out:
#              state  act_participation_2017  act_composite_2017  \
# 28          Nevada                     1.0                17.8
# 40  South Carolina                     1.0                18.7
# 24     Mississippi                     1.0                18.6
# 11          Hawaii                     0.9                19.0
# 0          Alabama                     1.0                19.2
#
#     act_participation_2018  act_composite_2018  sat_participation_2017  \
# 28                    1.00                17.7                    0.26
# 40                    1.00                18.3                    0.50
# 24                    1.00                18.6                    0.02
# 11                    0.89                18.9                    0.55
# 0                     1.00                19.1                    0.05
#
#     sat_total_2017  sat_participation_2018  sat_total_2018
# 28          1116.0                    0.23          1140.0
# ...

# %%
# States with max participation rate

act_2017_max = act_2017_df[act_2017_df['participation_2017']==1]['state']
act_2018_max = act_2018_df[act_2018_df['participation_2018']==1]['state']
sat_2017_max = sat_2017_df[sat_2017_df['participation_2017']==1]['state']
sat_2018_max = sat_2018_df[sat_2018_df['participation_2018']==1]['state']

sat_2018_max
# Out:
# 5        Colorado
# 6     Connecticut
# 7        Delaware
# 12          Idaho
# 22       Michigan
# Name: state, dtype: object

# %%
def check_max_part(df,df_2):
    
    """function to check if states continued their max participation rate"""
    
    isin_ = []
    notin_ = []
    
    for state in df:
        if state in df_2.values:
            isin_.append(state)
        else:
            notin_.append(state)
            
    display (f'States with 100% continuous participation: {isin_}', 
            f'States that did not continue 100% participation: {notin_}')

# %%
#check_max_part(act_2017_max,act_2018_max)
check_max_part(sat_2017_max,sat_2018_max)
# Out:
# "States with 100% continuous participation: ['Connecticut', 'Delaware', 'Michigan']"
# "States that did not continue 100% participation: ['District of Columbia']"

# %%
def more_than_percentage(act_df,sat_df,pct):
    
    """"function to check states that have more than 50% of students who take ACT and SAT in the same year"""
    
    act_temp_17 = act_df.loc[act_df['participation_2017']>pct]['state']

    act_temp_18 = act_df.loc[act_df['participation_2018']>pct]['state']

    sat_temp_17 = sat_df.loc[sat_df['participation_2017']>pct]['state']

    sat_temp_18 = sat_df.loc[sat_df['participation_2018']>pct]['state']
    
    list_1 = [state for state in act_temp_17 if state in sat_temp_17.values]
    
    list_2 = [state for state in act_temp_18 if state in sat_temp_18.values]
    
    display (f' 2017: {list_1}', f' 2018: {list_2}')

more_than_percentage(act_df,sat_df,0.5)
# Out:
# " 2017: ['Florida', 'Georgia', 'Hawaii']"
# " 2018: ['Florida', 'Georgia', 'Hawaii', 'North Carolina', 'South Carolina']"

# %%
# Median for colleges for ACT/SAT for both years

act_median_17 = np.median(act_df['composite_2017'])
    
act_median_18 = np.median(act_df['composite_2018'])
    
sat_median_17 = np.median(sat_df['total_2017'])
    
sat_median_18 = np.median(sat_df['total_2018'])

display(f'ACT median 2017: {act_median_17}',
     f'ACT median 2018: {act_median_18}',
     f'SAT median 2017: {sat_median_17}',
     f'SAT median 2018: {sat_median_18}'
     )
# Out:
# 'ACT median 2017: 21.4'
# 'ACT median 2018: 21.3'
# 'SAT median 2017: 1107.0'
# 'SAT median 2018: 1098.0'

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#heatmap for all features
sns.heatmap(exams_df.corr(),annot = True).set(title = 'Correlation of Features for SAT & ACT')
# Out:
# [Text(0.5, 1.0, 'Correlation of Features for SAT & ACT')]

# %%
#heatmap for all features but only lower triangle

mask = np.zeros_like(exams_df.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(exams_df.corr(),mask = mask, annot=True,cmap = 'autumn').set(title = 'Correlation of Features for SAT & ACT')
# Out:
# [Text(0.5, 1.0, 'Correlation of Features for SAT & ACT')]

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# The heatmap suggests that ACT participation rates are negatively correlated with ACT scores (2017: -0.86, 2018: -0.86).
# This is also seen in SAT (2017: -0.87, 2018: -0.79).
# Hence, the heatmap suggests that higher participation rates and compulsory participation will result in lower overall scores for the state.
#
# Interestingly, ACT scores are negatively correlated with SAT scores (2017: -0.45, 2018: -0.41). A possible explanation is that states will teach their curriculum focusing on a specific exam. Hence, students may not be well equipped to handle the other exam.
#
# As expected, we can observe that a state with high participation in the previous year is likely to have a high participation in the coming year for the same exam (positive correlation). States that have a high participation rate for any exam will have a low participation rate in the other exam (negative correlation). Moreover, states that do well in previous year's exam is likely to do well in the following year's exam (positive correlation).

# %%
#Plotting barcharts to compare participation rates of ACT/SAT in 2017/2018

plt.figure(figsize=(16,12))

plt.barh(exams_df['state'],exams_df['act_participation_2017'],label = 2017)

plt.barh(exams_df['state'],exams_df['act_participation_2018'],label = 2018,alpha = 0.5)

plt.title('ACT Participation Rate 2017 on 2018')
plt.xlabel('State')
plt.xlabel('Participation Rate')

plt.legend()

# %%
plt.figure(figsize=(16,12))

plt.barh(exams_df['state'],exams_df['sat_participation_2017'],label = 2017)

plt.barh(exams_df['state'],exams_df['sat_participation_2018'],label = 2018,alpha = 0.5)

plt.title('SAT Participation Rate 2017 on 2018')
plt.xlabel('State')
plt.xlabel('Participation Rate')

plt.legend()

# %%
#Inspecting states with huge jumps

exams_df[(exams_df['state'] == 'Colorado') | (exams_df['state'] =='Illinois') | (exams_df['state'] =='Alaska')]
# Out:
#        state  act_participation_2017  act_composite_2017  \
# 1     Alaska                    0.65                19.8
# 5   Colorado                    1.00                20.8
# 13  Illinois                    0.93                21.4
#
#     act_participation_2018  act_composite_2018  sat_participation_2017  \
# 1                     0.33                20.8                    0.38
# 5                     0.30                23.9                    0.11
# 13                    0.43                23.9                    0.09
#
#     sat_total_2017  sat_participation_2018  sat_total_2018
# 1           1080.0                    0.43          1106.0
# 5           1201.0                    1.00          1025.0
# 13          1115.0                    0.99          1019.0

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# From the barcharts, we can see that there were dramatic decreases in ACT for Illinois, Colorado and Alaska. Through further research, we found out that the decrease in ACT for Colorado <sup> 6 </sup> and Illinois <sup> 7 </sup> is due to a change in state policy mandating for students to switch from ACT to SAT, resulting in increases of ~90% in SAT participation rates for both states. For Alaska, we observed a 32% drop in ACT participation from 2017 to 2018, though we did not see any major increases in SAT. This could be due to the policy expiry of the state requiring students to take college aptitude tests in order to get a high school diploma <sup> 8 </sup>.

# %%
def plot_hist(df,list_of_inputs,y_label_input,title_input):
    
    """historgram plot function"""
    
    rows = int(np.ceil(len(list_of_inputs)/2))
    fig,ax = plt.subplots(rows,2,figsize=(15,10))
    
    ax = ax.ravel()

    for i, column in enumerate(list_of_inputs):
        ax[i].hist(df[column])
        
        ax[i].set_xlabel(str(column))
        ax[i].set_ylabel(y_label_input)
        
        mean = np.mean(df[column])
        ax[i].set_title(title_input + ' ' +column + f' (Mean: {round(mean,2)})')

        ax[i].axvline(mean,color = 'black')

    fig.tight_layout(h_pad = 1,w_pad = 10)

# %%
plot_hist(exams_df,['act_participation_2017','act_participation_2018','sat_participation_2017','sat_participation_2018'],
                   'Number of states','Frequency of states for')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# Through the histogram plots, we suspect that the participation rates for SAT and ACT follows a bimodal distribution. However, it is not too obvious from a histogram plot. Let us plot a distplot with a kernel density estimate (KDE) in order to better verify our analysis.

# %%
def dist_plot(df,list_of_inputs,y_label_input,title_input):
    
    """Plotting of distplot"""
    
    rows = int(np.ceil(len(list_of_inputs)/2))
    fig,ax = plt.subplots(rows,2,figsize=(15,10))
    
    ax = ax.ravel()

    for i, column in enumerate(list_of_inputs):
    
        sns.distplot(df[column],ax=ax[i],bins=10)

        ax[i].set_xlabel(str(column))
        ax[i].set_ylabel(y_label_input)
        
        mean = np.mean(df[column])
        ax[i].set_title(title_input + ' ' +column + f' (Mean: {round(mean,2)})')
        ax[i].axvline(mean,color = 'black')

    fig.tight_layout(h_pad = 1,w_pad = 10)

# %%
dist_plot(exams_df,['act_participation_2017','act_participation_2018','sat_participation_2017','sat_participation_2018'],
                   'Density','Distplot for')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# As we suspected, the participation rates follow a bimodal distribution, where most states either have low participation or high participation rates. We can however see that the ACT enjoys higher participation rates as the two peaks are clustered around 25% and 100% participation rates, while those of SAT is lower at 0% and 75%, resulting in a higher mean participation rate for ACT.

# %%
dist_plot(exams_df,['act_composite_2017','act_composite_2018','sat_total_2017','sat_total_2018'],
                   'Density','Distplot for')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# Similar to the participation rates, the state scores for ACT/SAT follow a bimodal distribution. The peaks of the distribution of each test scores are slightly lower than the mean. The distribution for both tests are both slightly positive skewed.

# %%
# Printing out descriptive stats

for column, row in exams_df.describe().T.iterrows():

    exam = column.split('_')[0].upper()
    value = column.split('_')[1]
    year = column.split('_')[2]
    mean = round(row["mean"],2)
    median = round(row["50%"],2)
    std = round(row["std"],2)
    pct_25 = round(row["25%"],2)
    pct_75 = round(row["75%"],2)
    
    print(f'For {exam} {year}, the {value} mean is {mean} and median is {median}')
    print(f'It has a standard deviation of {std} and its IQR is between {pct_25} and {pct_75}')
    print ()
# Out:
# For ACT 2017, the participation mean is 0.65 and median is 0.69
# It has a standard deviation of 0.32 and its IQR is between 0.31 and 1.0
#
# For ACT 2017, the composite mean is 21.52 and median is 21.4
# It has a standard deviation of 2.02 and its IQR is between 19.8 and 23.6
#
# For ACT 2018, the participation mean is 0.62 and median is 0.66
# It has a standard deviation of 0.34 and its IQR is between 0.29 and 1.0
#
# For ACT 2018, the composite mean is 21.5 and median is 21.3
# It has a standard deviation of 2.11 and its IQR is between 19.95 and 23.65
#
# For SAT 2017, the participation mean is 0.4 and median is 0.38
# It has a standard deviation of 0.35 and its IQR is between 0.04 and 0.66
#
# For SAT 2017, the total mean is 1126.1 and median is 1107.0
# It has a standard deviation of 92.49 and its IQR is between 1055.5 and 1212.0
#
# For SAT 2018, the participation mean is 0.46 and median is 0.52
# It has a standard deviation of 0.37 and its IQR is between 0.04 and 0.78
#
# ...

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# We observe that the ACT is more well received than the SAT as a large proportion of states have less than 10% participation rate for SAT, while the reverse is true for ACT where there is a large proportion of states that have more than 90% participation rate.
#
# The mean participation rate for ACT is ~60%, while the mean participation for SAT is ~40%. However, we notice that the mean ACT participation rate has decreased by approximately 3% from 2017 to 2018, while SAT participation has increased by approximately 6%.

# %%
#box plot function
def box_plot(df,list_of_col,title,ylabel):
    
    """Plotting of box plot"""
    
    fig,ax = plt.subplots(figsize=(8,6))
    
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    fig.tight_layout()
    
    for i,column in enumerate(list_of_col):
        sns.boxplot(data=df[list_of_col])

# %%
box_plot(exams_df,['act_participation_2017','act_participation_2018',
                   'sat_participation_2017','sat_participation_2018'],'Participation Rates','Rate')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# We can see that the median participation rate for ACT in 2018 has dropped as compared to 2017. This is mirrored by an increase in SAT participation rate. This could be because of certain states such as Colorado <sup>6</sup> and Illinois <sup>7</sup>, which switched from ACT to SAT. This is due to an assessment from the College Board of Illinois that opines that the SAT is a better exam to gauge a student's readiness. Moreover, the SAT also has more free resources, such as personalized online test practices through Khan Academy and college application fee waivers<sup>7</sup>. The interquartile range has also increased for both tests, suggesting greater variance in participation rates in 2018 as compared to 2017.

# %%
box_plot(exams_df,['act_composite_2017','act_composite_2018',],'ACT Scores','Scores')
box_plot(exams_df,['sat_total_2017','sat_total_2018'],'SAT Scores','Scores')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# We can see that the median scores decreased from 2017 to 2018 for both ACT and SAT. This could mean either the tests have been made harder in 2018, or that the students are weaker as compared to 2017. For SAT, we note that the third quartile (75th percentile) score also decreased in 2018.

# %%
def plot_scatter(df,list_of_x,list_of_y):
    
    """scatter plot function"""
    
    rows = int(np.ceil(len(list_of_x)/2))
    
    fig, ax = plt.subplots(rows,2,figsize= (12,8))
    
    ax = ax.ravel()
    
    for i,_ in enumerate(list_of_x):
        sns.regplot(data=df,x = list_of_x[i], y =list_of_y[i],ax=ax[i])
        ax[i].set_xlabel(list_of_x[i])
        ax[i].set_ylabel(list_of_y[i])
        ax[i].set_title(str(list_of_y[i])+ ' on ' + str(list_of_x[i]))
        plt.tight_layout()

# %%
plot_scatter(exams_df,['act_participation_2017','act_participation_2018','sat_participation_2017','sat_participation_2018'],
             ['act_composite_2017','act_composite_2018','sat_total_2017','sat_total_2018']
            )

# %%
#Normalizing SAT and ACT scores to plot all the regressions in 1 plot

from sklearn.preprocessing import MinMaxScaler

scaling = MinMaxScaler()

norm = scaling.fit_transform(exams_df[['sat_total_2017','act_composite_2017','sat_total_2018','act_composite_2018']])
sat_total_2017_norm = norm[:,0]
act_total_2017_norm = norm[:,1]
sat_total_2018_norm = norm[:,2]
act_total_2018_norm = norm[:,3]

plt.figure(figsize = (10,6))

sns.regplot(x = exams_df['sat_participation_2017'], y =sat_total_2017_norm, label = 'SAT 2017')
sns.regplot(x = exams_df['act_participation_2017'], y =act_total_2017_norm, label = 'ACT 2017')
sns.regplot(x = exams_df['sat_participation_2018'], y =sat_total_2018_norm, label = 'SAT 2018')
sns.regplot(x = exams_df['act_participation_2018'], y =act_total_2018_norm, label = 'ACT 2018')

plt.legend()
plt.title('Normalized Test Scores vs Participation')
plt.ylabel('Normalized Test Scores')
plt.xlabel('Participation Rates')
# Out:
# Text(0.5, 0, 'Participation Rates')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# From the downward slopping linear regression lines, we can see that for both SAT and ACT, there is a negative correlation between states' average exam scores and their respective exam participation rates. Though there is no positive correlation between exam scores and participation rates, it is still useful to identify the states that are underperforming, so that we can identify the states that have the most room for growth.

# %%
# Trying to find states that underperform (i.e below linear regression line) by labelling them

plt.figure(figsize = (20,10))
exams_df.reset_index(inplace=True,drop=True)

sns.regplot(data=exams_df,x = 'sat_participation_2018', y ='sat_total_2018')
        
for line in range(0,exams_df.shape[0]):
    
    plt.text(exams_df['sat_participation_2018'][line], exams_df['sat_total_2018'][line],
    exams_df['state'][line], horizontalalignment='left', 
    size='medium', color='black', weight='semibold')

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# We see that it is difficult to label a scatter plot as there are too many values. Moreover, it would be good if we could numerically identify the top underperforming states. Hence, we shall model the linear regression ourself and identify the states that underperform according to the model.

# %%
# Function to plot OLS and predict scores that the states should achieve according to their participation rates

import statsmodels.api as sm

def ols_plot(df,list_x,list_y):
    for i,_ in enumerate(list_x):

        dep_var = df[list_y[i]]
        indep_var = df[list_x[i]]
        indep_var_const = sm.add_constant(indep_var)

        model = sm.OLS(dep_var,indep_var_const)
        result = model.fit()
        print(result.summary())

        my_plot = plt.figure()
        my_plot = plt.plot(indep_var,dep_var,'ro')
        my_plot = plt.plot(indep_var,result.fittedvalues)

        plt.title(f'Linear Regression {list_y[i]} on {list_x[i]}')
        plt.ylabel('Exam Scores')
        plt.xlabel('Participation Rates')
        
        col = list_x[i]+'_predict'

        exams_df[col] = result.fittedvalues

# %%
ols_plot(exams_df,['act_participation_2017','act_participation_2018','sat_participation_2017','sat_participation_2018'],
             ['act_composite_2017','act_composite_2018','sat_total_2017','sat_total_2018'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     act_composite_2017   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     136.9
# Date:                Fri, 04 Mar 2022   Prob (F-statistic):           8.54e-16
# Time:                        02:02:26   Log-Likelihood:                -73.737
# No. Observations:                  51   AIC:                             151.5
# Df Residuals:                      49   BIC:                             155.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     25.0402      0.335     74.794      0.000      24.367      25.713
# ...

# %%
#creating a new df to store difference in the predictions and actual to find underperforming outliers

prediction_df = pd.DataFrame({'state':exams_df['state']})

prediction_df['sat_2017_diff'] = exams_df['sat_total_2017'] - exams_df['sat_participation_2017_predict']
prediction_df['sat_2018_diff'] = exams_df['sat_total_2018'] - exams_df['sat_participation_2018_predict']
prediction_df['act_2017_diff'] = exams_df['act_composite_2017'] - exams_df['act_participation_2017_predict']
prediction_df['act_2018_diff'] = exams_df['act_composite_2018'] - exams_df['act_participation_2018_predict']

prediction_df.head()
# Out:
#         state  sat_2017_diff  sat_2018_diff  act_2017_diff  act_2018_diff
# 0     Alabama     -40.265707     -32.839203      -0.445079      -0.345283
# 1      Alaska     -50.201377     -19.463487      -1.733360      -2.235226
# 2     Arizona     -32.398791      -4.227272      -1.995213      -2.067045
# 3    Arkansas      -1.815060     -31.822330      -0.245079      -0.045283
# 4  California     -41.081228     -15.750320      -0.567691      -0.656713

# %%
#Function to sort out the top 5 underperforming states for each exam per year

def top_5_states_to_target(df,column):
    low_5 = df.sort_values(by = column,ascending=True)[['state',column]].head()
    
    return low_5

# %%
display(top_5_states_to_target(prediction_df,'sat_2017_diff'))

temp_1 = top_5_states_to_target(prediction_df,'sat_2017_diff').reset_index(drop=True)

print(f'Top 5 underperforming states for SAT 2017: {temp_1["state"].ravel()}')
# Out:
#             state  sat_2017_diff
# 36       Oklahoma    -153.716354
# 48  West Virginia     -98.793617
# 13       Illinois     -81.167000
# 43          Texas     -55.609138
# 31     New Mexico     -53.617647
# Top 5 underperforming states for SAT 2017: ['Oklahoma' 'West Virginia' 'Illinois' 'Texas' 'New Mexico']

# %%
display(top_5_states_to_target(prediction_df,'sat_2018_diff'))

temp_2 = top_5_states_to_target(prediction_df,'sat_2018_diff').reset_index(drop=True)

print(f'Top 5 underperforming states for SAT 2018: {temp_2["state"].ravel()}')
# Out:
#             state  sat_2018_diff
# 44           Utah    -192.805458
# 48  West Virginia    -156.210399
# 36       Oklahoma    -132.872948
# 11         Hawaii     -89.682830
# 31     New Mexico     -86.007928
# Top 5 underperforming states for SAT 2018: ['Utah' 'West Virginia' 'Oklahoma' 'Hawaii' 'New Mexico']

# %%
display(top_5_states_to_target(prediction_df,'act_2017_diff'))

temp_3 = top_5_states_to_target(prediction_df,'act_2017_diff')

print(f'Top 5 underperforming states for ACT 2017: {temp_3["state"].ravel()}')
# Out:
#          state  act_2017_diff
# 2      Arizona      -1.995213
# 43       Texas      -1.912378
# 28      Nevada      -1.845079
# 31  New Mexico      -1.779409
# 1       Alaska      -1.733360
# Top 5 underperforming states for ACT 2017: ['Arizona' 'Texas' 'Nevada' 'New Mexico' 'Alaska']

# %%
display(top_5_states_to_target(prediction_df,'act_2018_diff'))

temp_4 = top_5_states_to_target(prediction_df,'act_2018_diff')

print(f'The top 5 underperforming states for ACT 2018: {temp_4["state"].ravel()}')
# Out:
#          state  act_2018_diff
# 1       Alaska      -2.235226
# 2      Arizona      -2.067045
# 31  New Mexico      -1.813464
# 28      Nevada      -1.745283
# 43       Texas      -1.692251
# The top 5 underperforming states for ACT 2018: ['Alaska' 'Arizona' 'New Mexico' 'Nevada' 'Texas']

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# The p-values for the coefficients are less than 1%, and hence we can accept them as significant and reject the null hypothesis that there is no correlation between participation rates and exam scores. Of the top states that are underperforming for ACT and SAT, the states of new Mexico and Texas are the most worrying, as they are the only states among the top 5 underperformers that underperformed for both ACT and SAT.

# %%
#Now, we would like to examine if ethnicities play a part in a state's scores
# 2022 Data from https://worldpopulationreview.com/states/states-by-race

ethnic_df = pd.read_csv('../data/EthnicData.csv').round(2)

display(ethnic_df.head())

display(ethnic_df.info())

ethnic_describe = ethnic_df.describe().round(2)

ethnic_describe
# Out:
#         State  WhiteTotalPerc  BlackTotalPerc  IndianTotalPerc  \
# 0     Alabama            0.68            0.27             0.01
# 1      Alaska            0.65            0.03             0.15
# 2     Arizona            0.77            0.04             0.04
# 3    Arkansas            0.77            0.15             0.01
# 4  California            0.60            0.06             0.01
#
#    AsianTotalPerc  HawaiianTotalPerc  OtherTotalPerc
# 0            0.01               0.00            0.03
# 1            0.06               0.01            0.10
# 2            0.03               0.00            0.10
# 3            0.02               0.00            0.05
# 4            0.14               0.00            0.19
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              52 non-null     object
# ...

# %%
def top_5_states_to_append(df,list_of_columns):
    
    """function to return a list of unique underperforming states for ACT and SAT"""
    
    list_of_states = []
    
    for col in list_of_columns:
        low_5 = df.sort_values(by = col,ascending=True)[['state',col]].head()
    
        for i in low_5['state']:
            if i not in list_of_states:
                list_of_states.append(i)
                
    return list_of_states

# %%
under_perform_list = top_5_states_to_append(prediction_df, ['act_2017_diff','act_2018_diff','sat_2017_diff','sat_2018_diff'])

under_perform_list
# Out:
# ['Arizona',
#  'Texas',
#  'Nevada',
#  'New Mexico',
#  'Alaska',
#  'Oklahoma',
#  'West Virginia',
#  'Illinois',
#  'Utah',
#  'Hawaii']

# %%
under_perform_df = ethnic_df[ethnic_df['State'].isin(under_perform_list)]

mean_df = ethnic_df.describe().loc['mean'] # Mean % of each ethnicity in each state

# %%
def plotbar(df, line_df, list_of_columns):
    
    """Function to plot barcharts"""
    
    rows = len(list_of_columns)
    fig,ax = plt.subplots(rows,1,figsize=(10,35))
    ax = ax.ravel()
    
    for i, column in enumerate(list_of_columns):
        ax[i].bar(df['State'],df[column]*100)
        ax[i].set_xlabel(str(column))
        ax[i].set_ylabel('percentage (%)')
        
        mean = line_df[i]*100
        ax[i].set_title(str(column) + f' by State (mean:{round(mean,2)}%)')
        
        ax[i].axhline(mean,color = 'black')
        fig.tight_layout(h_pad = 5)

# %%
#Plotting of bar charts for each ethnicity broken down by states

plotbar(under_perform_df, mean_df, under_perform_df.columns[1:])

# %% [markdown]
# ## <span style="color:green"> My Analysis:
#
# Through further examination of the ethnicity of the 10 underperforming states, we are able to identify a clear trend. Out of the 10 states, 9 of the states have higher than average 'Others' ethnicity.

# %% [markdown]
# ## <span style="color:green"> Restating Problem Statement:
#
# As an analyst in the United States Department of Education, I have been tasked to investigate if states that have a higher exam participation rate perform better than states with lower participation rates. If so, it would provide strong grounds for states to mandate that all students participate in the ACT/SAT.

# %% [markdown]
# ## <span style="color:green"> My Conclusions and Recommendations
#
# Due to the negative correlation between ACT/SAT scores and their respective participation rates, we cannot justify that mandating full participation of ACT/SAT for all students will lead to higher scores. This negative correlation could be caused by selection bias, as states who do not mandate or actively encourage students to take the ACT/SAT will result in only the best students choosing to sit for the exams as they know that they can score well <sup> 9 </sup>.
#
# Our study then dived deeper to identify the states that are underperforming as compared to the scores that they should be achieving according to their respective participation rates. The identified states are Arizona, Texas, Nevada, New Mexico, Alaska, Oklahoma, West Virginia, Illinois, Utah and Hawaii. The Department of Education can thus consider focusing their efforts in raising the education levels of these states as they have the most room for improvement. This is especially so for New Mexico and Texas, which are the among the worst under performers for both SAT and ACT.
#
# Moreover, on closer inspection, we notice that many of the underperforming states are in the south west region close to Mexico. This includes states such as Texas, Utah, Nevada, New Mexico, Arizona, Hawaii and Oaklahoma. Through closer examination of the breakdown in ethnicity, we note that states who have higher than average 'Others' ethnicity are in danger of underperforming. Due to the close proximity to the Mexican border, we hence suspect that a large percentage of the 'Others' category is made up of Hispanic Americans. Looking at state data for hispanic individuals in 2019 <sup> 3 </sup>, we can see that many underperforming states such as New Mexico, Texas, Arizona and Nevada are indeed states that have high hispanic populations. Moreover, even Illinois which is not in the South West, also has a relatively high hispanic population at 17.5%. Further research shows that certain states such as Texas and Illinois are not awarded equal amounts of education funding, which is a significant factor as funds do play a part in raising education level <sup> 5 </sup>. Hence, we must make sure that adequate resources are provided to people of 'Others' ethnicity, to improve the overall education level of the state.

# %% [markdown]
# ## <span style="color:green"> My Outside Research:
#
# 1. https://www.act.org/content/dam/act/unsecured/documents/cccr2017/CCCR_National_2017.pdf (ACT participation figures)
#
# 2. https://reports.collegeboard.org/archive/sat-suite-program-results/2017/overview#:~:text=The%20class%20of%202017%20is,takers%20took%20the%20new%20SAT (SAT participation figures)
#
# 3. https://www.statista.com/statistics/259865/percentage-of-hispanic-population-in-the-us-by-state/ (Hispanic Breakdown)
#
# 4. https://worldpopulationreview.com/states/states-by-race (Breakdown by Ethnicity)
#
# 5. https://cdn.americanprogress.org/content/uploads/2018/11/08042733/LessonsLearned_SchoolFunding-report-4.pdf (Less funding)
#
# 6. https://www.coloradoindependent.com/2017/07/06/from-csap-to-parcc-heres-how-colorados-standardized-tests-have-changed-and-whats-next/ (Colorado switch to SAT)
#
# 7. https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html (Illinois switch to SAT)
#
# 8. https://www.alaskapublic.org/2016/07/01/alaska-changes-hs-diploma-requirements-no-more-sat-act/ (Alaska drop ACT/SAT for diploma)
#
# 9. https://blog.prepscholar.com/average-sat-and-act-scores-by-stated-adjusted-for-participation-rate (Selection Bias of participation rates)
